# %%
import pandas as pd
import numpy as np

# %%
monthly=pd.read_csv("C:\\Users\\Govind S\\Downloads\\ds\\project\\2nd project\\monthly.csv")

# %%
monthly
# Out:
#              Month  Open Price  High Price  Low Price  Close Price  \
# 0     January-2016      1010.0     1089.50     978.15      1035.05
# 1    February-2016      1040.0     1041.00     888.50       966.55
# 2       March-2016       967.5     1055.95     965.00      1045.25
# 3       April-2016      1039.0     1070.00     977.85       982.55
# 4         May-2016       981.4      994.70     925.70       958.95
# ..             ...         ...         ...        ...          ...
# 78       July-2022      2580.0     2591.65    2365.00      2508.75
# 79     August-2022      2513.0     2677.60    2507.95      2639.10
# 80  September-2022      2589.1     2628.55    2313.55      2377.70
# 81    October-2022      2397.0     2560.50    2343.60      2549.55
# 82   November-2022      2582.0     2588.45    2508.00      2529.75
#
#     No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0       17971880         345349          1.836299e+10               9160077
# ...

# %%
monthly['Total Turnover (Rs.)']
# Out:
# 0     1.836299e+10
# 1     9.947374e+09
# 2     9.164079e+09
# 3     5.504296e+09
# 4     4.762539e+09
#           ...
# 78    2.996946e+10
# 79    2.001336e+10
# 80    2.017432e+10
# 81    2.438283e+10
# 82    4.962272e+08
# Name: Total Turnover (Rs.), Length: 83, dtype: float64

# %%
monthly.columns
# Out:
# Index(['Month', 'Open Price', 'High Price', 'Low Price', 'Close Price',
#        'No.of Shares', 'No. of Trades', 'Total Turnover (Rs.)',
#        'Deliverable Quantity', '% Deli. Qty to Traded Qty', 'Spread High-Low',
#        'Spread Close-Open'],
#       dtype='object')

# %%
monthly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Month                      83 non-null     object
#  1   Open Price                 83 non-null     float64
#  2   High Price                 83 non-null     float64
#  3   Low Price                  83 non-null     float64
#  4   Close Price                83 non-null     float64
#  5   No.of Shares               83 non-null     int64
#  6   No. of Trades              83 non-null     int64
#  7   Total Turnover (Rs.)       83 non-null     float64
#  8   Deliverable Quantity       83 non-null     int64
#  9   % Deli. Qty to Traded Qty  83 non-null     float64
#  10  Spread High-Low            83 non-null     float64
#  11  Spread Close-Open          83 non-null     float64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 7.9+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.lineplot(x=monthly.index,y=monthly['Open Price'])
# Out:
# <AxesSubplot:ylabel='Open Price'>

# %%
sns.lineplot(x=monthly.index,y=monthly['High Price'])
# Out:
# <AxesSubplot:ylabel='High Price'>

# %%
sns.lineplot(x=monthly.index,y=monthly['Low Price'])
# Out:
# <AxesSubplot:ylabel='Low Price'>

# %%
sns.lineplot(x=monthly.index,y=monthly['Close Price'])
# Out:
# <AxesSubplot:ylabel='Close Price'>

# %%
monthly.iloc[18:25,:]
# Out:
#              Month  Open Price  High Price  Low Price  Close Price  \
# 18       July-2017     1388.00      1631.1    1372.10      1613.85
# 19     August-2017     1623.85      1665.0    1530.00      1593.50
# 20  September-2017     1601.80      1652.4     780.00       782.15
# 21    October-2017      792.35       958.2     786.25       940.80
# 22   November-2017      946.00       959.0     873.00       922.60
# 23   December-2017      925.00       937.0     861.70       921.05
# 24    January-2018      922.00       990.0     907.25       961.15
#
#     No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 18       9690182         242574          1.487011e+10               3141792
# 19       5120100         167192          8.136976e+09               1848351
# 20      12317360         179213          1.274602e+10               5878188
# 21      13174254         173811          1.190287e+10               7357071
# ...

# %%
daily=pd.read_csv("C:\\Users\\Govind S\\Downloads\\ds\\project\\2nd project\\daily.csv")

# %%
daily
# Out:
#                  Date  Open Price  High Price  Low Price  Close Price  \
# 0     1-November-2022     2582.00     2588.45    2508.00      2529.75
# 1     31-October-2022     2535.00     2560.50    2533.10      2549.55
# 2     28-October-2022     2463.05     2534.00    2460.20      2526.00
# 3     27-October-2022     2456.00     2468.00    2433.20      2450.10
# 4     25-October-2022     2498.00     2498.15    2437.55      2441.85
# ...               ...         ...         ...        ...          ...
# 1687   7-January-2016     1023.80     1027.60    1008.25      1011.55
# 1688   6-January-2016     1005.00     1038.00    1000.55      1031.95
# 1689   5-January-2016     1002.00     1010.00     996.85      1005.10
# 1690   4-January-2016     1006.00     1014.20     987.30       995.40
# 1691   1-January-2016     1010.00     1020.00    1008.75      1015.35
#
#               WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# ...

# %%
type(daily.Date[0])
# Out:
# str

# %%
import datetime

# %%
pd.to_datetime(daily.Date)
# Out:
# 0      2022-11-01
# 1      2022-10-31
# 2      2022-10-28
# 3      2022-10-27
# 4      2022-10-25
#           ...
# 1687   2016-01-07
# 1688   2016-01-06
# 1689   2016-01-05
# 1690   2016-01-04
# 1691   2016-01-01
# Name: Date, Length: 1692, dtype: datetime64[ns]

# %%
daily['date_2']=pd.to_datetime(daily.Date)

# %%
daily
# Out:
#                  Date  Open Price  High Price  Low Price  Close Price  \
# 0     1-November-2022     2582.00     2588.45    2508.00      2529.75
# 1     31-October-2022     2535.00     2560.50    2533.10      2549.55
# 2     28-October-2022     2463.05     2534.00    2460.20      2526.00
# 3     27-October-2022     2456.00     2468.00    2433.20      2450.10
# 4     25-October-2022     2498.00     2498.15    2437.55      2441.85
# ...               ...         ...         ...        ...          ...
# 1687   7-January-2016     1023.80     1027.60    1008.25      1011.55
# 1688   6-January-2016     1005.00     1038.00    1000.55      1031.95
# 1689   5-January-2016     1002.00     1010.00     996.85      1005.10
# 1690   4-January-2016     1006.00     1014.20     987.30       995.40
# 1691   1-January-2016     1010.00     1020.00    1008.75      1015.35
#
#               WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# ...

# %%
daily['date_2']=pd.to_datetime(daily.Date)
start=daily.iloc[-1,-1]
end=daily.iloc[0,-1]
dates=[start+datetime.timedelta(days=x) for x in range(0,(end-start).days)]
len(dates)
# Out:
# 2496

# %%
dates
# Out:
# [Timestamp('2016-01-01 00:00:00'),
#  Timestamp('2016-01-02 00:00:00'),
#  Timestamp('2016-01-03 00:00:00'),
#  Timestamp('2016-01-04 00:00:00'),
#  Timestamp('2016-01-05 00:00:00'),
#  Timestamp('2016-01-06 00:00:00'),
#  Timestamp('2016-01-07 00:00:00'),
#  Timestamp('2016-01-08 00:00:00'),
#  Timestamp('2016-01-09 00:00:00'),
#  Timestamp('2016-01-10 00:00:00'),
#  Timestamp('2016-01-11 00:00:00'),
#  Timestamp('2016-01-12 00:00:00'),
#  Timestamp('2016-01-13 00:00:00'),
#  Timestamp('2016-01-14 00:00:00'),
#  Timestamp('2016-01-15 00:00:00'),
#  Timestamp('2016-01-16 00:00:00'),
#  Timestamp('2016-01-17 00:00:00'),
#  Timestamp('2016-01-18 00:00:00'),
#  Timestamp('2016-01-19 00:00:00'),
#  Timestamp('2016-01-20 00:00:00'),
#  Timestamp('2016-01-21 00:00:00'),
#  Timestamp('2016-01-22 00:00:00'),
#  Timestamp('2016-01-23 00:00:00'),
#  Timestamp('2016-01-24 00:00:00'),
#  Timestamp('2016-01-25 00:00:00'),
#  Timestamp('2016-01-26 00:00:00'),
#  Timestamp('2016-01-27 00:00:00'),
# ...

# %%
b=daily[daily.date_2==dates[0]]["High Price"]
b.index[0]
# Out:
# 1691

# %%
len(daily[daily.date_2==dates[1]]["High Price"])
# Out:
# 0

# %%
prices=[]
for i in dates:
    a=daily[daily.date_2==i]["High Price"]
    if len(a)==0:
        prices.append(j)
    else:
        prices.append(a.iloc[0])
        close=daily[daily.date_2==i]["Close Price"].iloc[0]
        try:
            new_open=daily.loc[a.index[0]-1,"Open Price"]
            j=(close+new_open)/2
        except:
            continue

# %%
len(prices)
# Out:
# 2496

# %%
prices
# Out:
# [1020.0,
#  1010.675,
#  1010.675,
#  1014.2,
#  1010.0,
#  1038.0,
#  1027.6,
#  1032.15,
#  1017.525,
#  1017.525,
#  1059.95,
#  1065.0,
#  1087.4,
#  1081.0,
#  1089.5,
#  1073.1,
#  1073.1,
#  1082.45,
#  1049.0,
#  1040.5,
#  1025.7,
#  1010.15,
#  1006.075,
#  1006.075,
#  1018.4,
#  1006.375,
#  1009.7,
#  1021.75,
#  1039.4,
#  1037.525,
#  1037.525,
#  1041.0,
#  1032.0,
#  993.2,
#  1000.0,
#  982.0,
#  972.0999999999999,
#  972.0999999999999,
#  984.25,
#  968.5,
#  972.9,
#  966.0,
#  933.0,
#  913.65,
#  913.65,
#  949.95,
#  958.0,
#  956.0,
#  967.75,
#  952.45,
#  945.2249999999999,
#  945.2249999999999,
#  967.9,
#  966.9,
#  959.0,
#  957.0,
#  958.5,
#  950.8,
#  950.8,
#  993.0,
#  985.0,
#  1005.25,
#  1017.25,
#  1018.0,
#  1006.25,
#  1006.25,
#  1006.25,
#  1031.0,
#  1044.0,
#  1045.0,
#  1029.5,
#  1016.9,
#  1016.9,
#  1026.0,
#  1026.95,
#  1025.7,
#  1036.4,
#  1028.4,
#  1026.2,
#  1026.2,
#  1039.0,
#  1052.5,
#  1047.0,
#  1029.175,
#  1029.175,
# ...

# %%
daily.tail(15)
# Out:
#                  Date  Open Price  High Price  Low Price  Close Price  \
# 1677  21-January-2016     1016.30     1025.70     978.15       984.90
# 1678  20-January-2016     1040.50     1040.50     990.50      1004.35
# 1679  19-January-2016     1025.00     1049.00    1015.20      1043.60
# 1680  18-January-2016     1073.05     1082.45    1010.10      1018.00
# 1681  15-January-2016     1070.00     1089.50    1066.00      1073.15
# 1682  14-January-2016     1062.10     1081.00    1052.40      1061.20
# 1683  13-January-2016     1054.80     1087.40    1019.35      1077.35
# 1684  12-January-2016     1054.00     1065.00    1041.05      1045.10
# 1685  11-January-2016     1011.00     1059.95    1011.00      1051.55
# 1686   8-January-2016     1019.00     1032.15    1000.05      1024.05
# 1687   7-January-2016     1023.80     1027.60    1008.25      1011.55
# 1688   6-January-2016     1005.00     1038.00    1000.55      1031.95
# ...

# %%
daily_high=pd.DataFrame({"Date":dates,"High_Price":prices})
daily_high["High_Price"].plot(kind="line")
# Out:
# <AxesSubplot:>

# %%
low_prices=[]
for i in dates:
    a=daily[daily.date_2==i]["Low Price"]
    if len(a)==0:
        low_prices.append(j)
    else:
        low_prices.append(a.iloc[0])
        close=daily[daily.date_2==i]["Close Price"].iloc[0]
        try:
            new_open=daily.loc[a.index[0]-1,"Open Price"]
            j=(close+new_open)/2
        except:
            continue

# %%
low_prices
# Out:
# [1008.75,
#  1010.675,
#  1010.675,
#  987.3,
#  996.85,
#  1000.55,
#  1008.25,
#  1000.05,
#  1017.525,
#  1017.525,
#  1011.0,
#  1041.05,
#  1019.35,
#  1052.4,
#  1066.0,
#  1073.1,
#  1073.1,
#  1010.1,
#  1015.2,
#  990.5,
#  978.15,
#  994.75,
#  1006.075,
#  1006.075,
#  1000.15,
#  1006.375,
#  996.15,
#  997.75,
#  1018.85,
#  1037.525,
#  1037.525,
#  1025.15,
#  990.3,
#  975.0,
#  968.0,
#  963.0,
#  972.0999999999999,
#  972.0999999999999,
#  957.7,
#  950.35,
#  948.95,
#  916.25,
#  888.5,
#  913.65,
#  913.65,
#  920.0,
#  927.0,
#  917.1,
#  936.3,
#  937.8,
#  945.2249999999999,
#  945.2249999999999,
#  945.05,
#  943.05,
#  942.55,
#  941.7,
#  944.95,
#  950.8,
#  950.8,
#  936.3,
#  965.0,
#  987.5,
#  997.55,
#  1003.75,
#  1006.25,
#  1006.25,
#  1006.25,
#  1006.0,
#  1017.35,
#  1009.0,
#  1011.3,
#  1016.9,
#  1016.9,
#  1013.0,
#  1016.0,
#  1005.4,
#  1012.4,
#  1016.25,
#  1026.2,
#  1026.2,
#  1023.5,
#  1036.75,
#  1023.0,
#  1029.175,
#  1029.175,
# ...

# %%
len(low_prices)
# Out:
# 2496

# %%
daily_low=pd.DataFrame({"Date":dates,"Low_Price":low_prices})
daily_low["Low_Price"].plot(kind="line")
# Out:
# <AxesSubplot:>

# %%
daily_high.to_csv("daily_high.csv",index=False)

# %%
daily_low.to_csv("daily_low.csv",index=False)
